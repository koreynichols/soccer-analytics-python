# %%
import requests

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    'dnt': '1',
    'if-none-match': 'W/"b1580224c6"',
    'origin': 'https://www.sofascore.com',
    'priority': 'u=1, i',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
}

response = requests.get('https://api.sofascore.com/api/v1/event/11253247/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

import pandas as pd

df = pd.DataFrame(data['shotmap'])

# %%
df.head(5)
# Out:
#                                               player  isHome shotType  \
# 0  {'name': 'Pauline Bremer', 'firstName': '', 'l...    True     save
# 1  {'name': 'Lucy Bronze', 'firstName': '', 'last...    True    block
# 2  {'name': 'Patricia Guijarro', 'slug': 'patrici...    True    block
# 3  {'name': 'Aitana Bonmatí', 'firstName': '', 'l...    True     save
# 4  {'name': 'Geyse Ferreira', 'firstName': '', 'l...   False     miss
#
#     situation                                  playerCoordinates    bodyPart  \
# 0      corner         {'x': 1.2832537327796016, 'y': 54, 'z': 0}        head
# 1      corner  {'x': 3.953792893392321, 'y': 34.0916371226285...        head
# 2   set-piece  {'x': 13.178880816657625, 'y': 71.747937874031...        head
# 3    assisted  {'x': 3.094729046722488, 'y': 38.2926965382975...  right-foot
# 4  fast-break  {'x': 16.28376268015845, 'y': 8.19568192096213...  right-foot
#
#   goalMouthLocation                          goalMouthCoordinates  \
# 0       high-centre   {'x': 0, 'y': 75.67371210335439, 'z': 21.5}
# 1        low-centre     {'x': 0, 'y': 82.75192078623478, 'z': 19}
# 2        low-centre     {'x': 0, 'y': 92.29283645288336, 'z': 19}
# 3        low-centre   {'x': 0, 'y': 64.13379929475799, 'z': 17.1}
# 4        high-right  {'x': 0, 'y': 40.854241142983156, 'z': 66.7}
#
#                                     blockCoordinates       id  time  \
# 0           {'x': 1, 'y': 72.48297620841296, 'z': 0}  2068363    81
# 1  {'x': 0.3950699171918868, 'y': 13.309532429578...  2068297    72
# 2          {'x': 3.732748990760034, 'y': 44, 'z': 0}  2068287    83
# 3  {'x': 0.1793662489747052, 'y': 90.870299130497...  2068275    82
# 4                                                NaN  2068267    66
#
#    addedTime  timeSeconds                                               draw  \
# 0        9.0         5910  {'start': {'x': 54, 'y': 7.75810546820611}, 'b...
# 1        NaN         4748  {'start': {'x': 12.215904227964572, 'y': 0.888...
# 2        NaN         4675  {'start': {'x': 63.85802779385288, 'y': 0.9346...
# 3        NaN         4511  {'start': {'x': 81.26663739932692, 'y': 29.465...
# 4        NaN         4295  {'start': {'x': 27.776840682915804, 'y': 9.879...
#
#    reversedPeriodTime  reversedPeriodTimeSeconds incidentType goalType
# 0                   1                        390         shot      NaN
# 1                  11                        652         shot      NaN
# 2                  13                        725         shot      NaN
# 3                  15                        889         shot      NaN
# 4                  19                       1105         shot      NaN

# %%
url = 'https://www.sofascore.com/tsg-hoffenheim-vfl-bochum-1848/Rabsubb#id:11396203'

# %%
match_id = url.split('id:')[-1]

# %%
match_id
# Out:
# '11396203'

# %%
response = requests.get(f'https://api.sofascore.com/api/v1/event/{match_id}/shotmap', headers=headers)

# %%
response.json()
# Out:
# {'shotmap': [{'player': {'name': 'Marius Bülter',
#     'slug': 'marius-bulter',
#     'shortName': 'M. Bülter',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 317,
#     'id': 378340,
#     'fieldTranslations': {'nameTranslation': {'ar': 'بولتر ، ماريوس'},
#      'shortNameTranslation': {'ar': 'ب. ، ماريوس'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 38.23845799529692,
#     'y': 65.48570403667746,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 37.75207774476267, 'z': 62.5},
#    'xg': 0.016776576638222,
#    'id': 2772519,
#    'time': 88,
#    'addedTime': 4,
#    'timeSeconds': 5620,
#    'draw': {'start': {'x': 31.76005666992431, 'y': 50.097519677537356},
#     'end': {'x': 5.8258278224288915, 'y': 0},
#     'goal': {'x': 84.5756325836664, 'y': 10.916384994031603}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 680,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Takuma Asano',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'takuma-asano',
#     'shortName': 'T. Asano',
#     'position': 'F',
#     'jerseyNumber': '11',
#     'userCount': 1809,
#     'id': 309546,
#     'fieldTranslations': {'nameTranslation': {'ar': 'تاكوما اسانو'},
#      'shortNameTranslation': {'ar': 'ت. اسانو'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'fast-break',
#    'playerCoordinates': {'x': 4.843868226647901,
#     'y': 57.759845374644826,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'left',
#    'goalMouthCoordinates': {'x': 0, 'y': 100, 'z': 4.2},
#    'xg': 0.41105824708939,
#    'id': 2772509,
#    'time': 87,
#    'addedTime': 3,
#    'timeSeconds': 5527,
#    'draw': {'start': {'x': 30.680569004062303, 'y': 3.0941255581700506},
#     'end': {'x': 61.94169144957128, 'y': 0},
#     'goal': {'x': 27.191324349035654, 'y': 100}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 773,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Ozan Kabak',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'ozan-kabak',
#     'shortName': 'O. Kabak',
#     'position': 'D',
#     'jerseyNumber': '5',
#     'userCount': 3398,
#     'id': 857740,
#     'fieldTranslations': {'nameTranslation': {'ar': 'اوزان كاباك'},
#      'shortNameTranslation': {'ar': 'ا. كاباك'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 14.111836480034027,
#     'y': 65.18460708780195,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 7.426684064536097, 'z': 17.7},
#    'blockCoordinates': {'x': 0.2422985681498242,
#     'y': 45.937691381551424,
#     'z': 0},
#    'xg': 0.028894878923893,
#    'xgot': 0.032,
#    'id': 2772493,
#    'time': 95,
#    'timeSeconds': 5344,
#    'draw': {'start': {'x': 42.518007135586615, 'y': 7.004953370168829},
#     'block': {'x': 31.207858252385314, 'y': 2.970898897275526},
#     'end': {'x': 50.44839598800577, 'y': 0},
#     'goal': {'x': 48.48448129696597, 'y': 17.23449571529281}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 56,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Ivan Ordets',
#     'slug': 'ivan-ordets',
#     'shortName': 'I. Ordets',
#     'position': 'D',
#     'jerseyNumber': '20',
#     'userCount': 153,
#     'id': 137673,
#     'fieldTranslations': {'nameTranslation': {'ar': 'إيفان أورديت'},
#      'shortNameTranslation': {'ar': 'إ. أورديت'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 1.9644950553699916,
#     'y': 11.260311063176907,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 85.36285995262568, 'z': 19},
#    'blockCoordinates': {'x': 1.6200373381896291,
#     'y': 66.87590386979616,
#     'z': 0},
#    'xg': 0.12854644656181,
#    'id': 2772473,
#    'time': 94,
#    'timeSeconds': 5099,
#    'draw': {'start': {'x': 61.41189317091989, 'y': 8.044791803760035},
#     'block': {'x': 69.5304480055996, 'y': 7.2337715513559875},
#     'end': {'x': 81.20115241520577, 'y': 0},
#     'goal': {'x': 53.04504248444518, 'y': 81}},
#    'reversedPeriodTime': 6,
#    'reversedPeriodTimeSeconds': 301,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Andrej Kramarić',
#     'slug': 'andrej-kramaric',
#     'shortName': 'A. Kramarić',
#     'position': 'F',
#     'jerseyNumber': '27',
#     'userCount': 6371,
#     'id': 67647,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كراماريك, أندري'},
#      'shortNameTranslation': {'ar': 'أ. كراماريك'}}},
#    'isHome': False,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 3.534865954229769, 'y': 35, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 70.9739382135077, 'z': 22.2},
#    'xg': 0.077177442610264,
#    'xgot': 0.2665,
#    'id': 2772462,
#    'time': 88,
#    'timeSeconds': 5010,
#    'draw': {'start': {'x': 35, 'y': 10.313627722776129},
#     'end': {'x': 64.72711272387028, 'y': 0},
#     'goal': {'x': 93.70888722984206, 'y': 77.07829427904873}},
#    'reversedPeriodTime': 7,
#    'reversedPeriodTimeSeconds': 390,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Matúš Bero',
#     'slug': 'matus-bero',
#     'shortName': 'M. Bero',
#     'position': 'M',
#     'jerseyNumber': '19',
#     'userCount': 320,
#     'id': 187207,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ماتوس بيرو'},
#      'shortNameTranslation': {'ar': 'م. بيرو'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 0.5802890580151541, 'y': 40, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 64.01093824787851, 'z': 19},
#    'blockCoordinates': {'x': 36.1544324741086, 'y': 51.89770923858792, 'z': 0},
#    'xg': 0.0080832242965698,
#    'id': 2772445,
#    'time': 84,
#    'timeSeconds': 4784,
#    'draw': {'start': {'x': 40, 'y': 13.71166688442132},
#     'block': {'x': 20.210792459943654, 'y': 18.364955599817627},
#     'end': {'x': 70.19767586910454, 'y': 0},
#     'goal': {'x': 98.95315213608099, 'y': 81}},
#    'reversedPeriodTime': 11,
#    'reversedPeriodTimeSeconds': 616,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Felix Passlack',
#     'slug': 'passlack-felix',
#     'shortName': 'F. Passlack',
#     'position': 'M',
#     'jerseyNumber': '15',
#     'userCount': 360,
#     'id': 795000,
#     'fieldTranslations': {'nameTranslation': {'ar': 'باسلاك, فيليكس'},
#      'shortNameTranslation': {'ar': 'ف. باسلاك'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 15.571952896911863,
#     'y': 70.28680260779542,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 51.88500445515867, 'z': 32.9},
#    'blockCoordinates': {'x': 1.2257426716695556,
#     'y': 39.18808533534762,
#     'z': 0},
#    'xg': 0.030250951647758,
#    'xgot': 0.1244,
#    'id': 2772437,
#    'time': 88,
#    'timeSeconds': 4733,
#    'draw': {'start': {'x': 67.87599603160673, 'y': 9.868084687010072},
#     'block': {'x': 55.225959614840974, 'y': 1.0532944496127554},
#     'end': {'x': 39.27546063556701, 'y': 0},
#     'goal': {'x': 2.4739997744097764, 'y': 41.0003131783796}},
#    'reversedPeriodTime': 12,
#    'reversedPeriodTimeSeconds': 667,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Keven Schlotterbeck',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'keven-schlotterbeck',
#     'shortName': 'K. Schlotterbeck',
#     'position': 'D',
#     'jerseyNumber': '31',
#     'userCount': 383,
#     'id': 891651,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شلوتيربيك, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شلوتيربيك'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 2.142662293340384,
#     'y': 72.08574617848681,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 68.63787331574683, 'z': 19},
#    'blockCoordinates': {'x': 3.8489706784659266, 'y': 57, 'z': 0},
#    'xg': 0.091505967080593,
#    'id': 2772434,
#    'time': 69,
#    'timeSeconds': 4690,
#    'draw': {'start': {'x': 32.630080892160166, 'y': 2.7063785409392103},
#     'block': {'x': 57, 'y': 4.297509129291248},
#     'end': {'x': 38.746236547905795, 'y': 0},
#     'goal': {'x': 66.73197216861635, 'y': 81}},
#    'reversedPeriodTime': 12,
#    'reversedPeriodTimeSeconds': 710,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Keven Schlotterbeck',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'keven-schlotterbeck',
#     'shortName': 'K. Schlotterbeck',
#     'position': 'D',
#     'jerseyNumber': '31',
#     'userCount': 383,
#     'id': 891651,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شلوتيربيك, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شلوتيربيك'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 13.611988185594013, 'y': 100, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 53.45381542602137, 'z': 19},
#    'blockCoordinates': {'x': 5, 'y': 97.52094223250253, 'z': 0},
#    'xg': 0.071450717747211,
#    'id': 2772432,
#    'time': 76,
#    'timeSeconds': 4688,
#    'draw': {'start': {'x': 27.12756760164458, 'y': 3.6084384680396173},
#     'block': {'x': 7.570588952751493, 'y': 5},
#     'end': {'x': 74.64229901150583, 'y': 0},
#     'goal': {'x': 49.069153359182856, 'y': 81}},
#    'reversedPeriodTime': 12,
#    'reversedPeriodTimeSeconds': 712,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Andrej Kramarić',
#     'slug': 'andrej-kramaric',
#     'shortName': 'A. Kramarić',
#     'position': 'F',
#     'jerseyNumber': '27',
#     'userCount': 6371,
#     'id': 67647,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كراماريك, أندري'},
#      'shortNameTranslation': {'ar': 'أ. كراماريك'}}},
#    'isHome': False,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 0.8097566381073635,
#     'y': 26.572077288812466,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 36.739187180069635, 'z': 13.3},
#    'xg': 0.47636443376541,
#    'xgot': 0.9647,
#    'id': 2772403,
#    'time': 64,
#    'timeSeconds': 4369,
#    'draw': {'start': {'x': 41.270921685076885, 'y': 1.958493901218759},
#     'end': {'x': 23.42732358112795, 'y': 0},
#     'goal': {'x': 93.7936158796668, 'y': 99.28670570807292}},
#    'reversedPeriodTime': 18,
#    'reversedPeriodTimeSeconds': 1031,
#    'incidentType': 'shot'},
#   {'player': {'name': 'David Jurásek',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'david-jurasek',
#     'shortName': 'D. Jurásek',
#     'position': 'D',
#     'jerseyNumber': '19',
#     'userCount': 766,
#     'id': 1030711,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ديفيد يوراسيك'},
#      'shortNameTranslation': {'ar': 'د. يوراسيك'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 14.505428421663893,
#     'y': 28.667168550358568,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 11.42914890137886, 'z': 19},
#    'blockCoordinates': {'x': 5.319924289247515,
#     'y': 59.95649414491511,
#     'z': 0},
#    'xg': 0.069827750325203,
#    'id': 2772408,
#    'time': 70,
#    'timeSeconds': 4367,
#    'draw': {'start': {'x': 68.80354238185063, 'y': 17.055357753469398},
#     'block': {'x': 41.663884324313315, 'y': 4.788776104409736},
#     'end': {'x': 87.16293104317603, 'y': 0},
#     'goal': {'x': 73.32642549458393, 'y': 81}},
#    'reversedPeriodTime': 18,
#    'reversedPeriodTimeSeconds': 1033,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Maximilian Wittek',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'maximilian-wittek',
#     'shortName': 'M. Wittek',
#     'position': 'D',
#     'jerseyNumber': '32',
#     'userCount': 170,
#     'id': 254125,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ماكسيميليان ويتك'},
#      'shortNameTranslation': {'ar': 'م. ويتك'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 13.331040808933922,
#     'y': 16.572160768974165,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 24.300972074835784, 'z': 19},
#    'blockCoordinates': {'x': 1.9790999531022209, 'y': 37, 'z': 0},
#    'xg': 0.11639211326838,
#    'id': 2772384,
#    'time': 60,
#    'timeSeconds': 4055,
#    'draw': {'start': {'x': 50.168748079365976, 'y': 9.406654094831554},
#     'block': {'x': 37, 'y': 11.33289157750673},
#     'end': {'x': 19.531554779844853, 'y': 0},
#     'goal': {'x': 63.17184688827041, 'y': 81}},
#    'reversedPeriodTime': 23,
#    'reversedPeriodTimeSeconds': 1345,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kevin Stöger',
#     'slug': 'kevin-stoger',
#     'shortName': 'K. Stöger',
#     'position': 'M',
#     'jerseyNumber': '7',
#     'userCount': 650,
#     'id': 95381,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شتوغر, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شتوغر'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 13, 'y': 100, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 32.24976746411918, 'z': 19},
#    'blockCoordinates': {'x': 10.237685551405955,
#     'y': 72.05903711709325,
#     'z': 0},
#    'xg': 0.022403502836823,
#    'id': 2772377,
#    'time': 66,
#    'timeSeconds': 3976,
#    'draw': {'start': {'x': 14.916882339917066, 'y': 13},
#     'block': {'x': 91.18055664920016, 'y': 5.9320631035815214},
#     'end': {'x': 2.1687547921752994, 'y': 0},
#     'goal': {'x': 92.91268467539737, 'y': 81}},
#    'reversedPeriodTime': 24,
#    'reversedPeriodTimeSeconds': 1424,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kevin Stöger',
#     'slug': 'kevin-stoger',
#     'shortName': 'K. Stöger',
#     'position': 'M',
#     'jerseyNumber': '7',
#     'userCount': 650,
#     'id': 95381,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شتوغر, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شتوغر'}}},
#    'isHome': False,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 7, 'y': 33.18980052275218, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 42.08543546621076, 'z': 5.7},
#    'xg': 0.23349326848984,
#    'xgot': 0.2611,
#    'id': 2772368,
#    'time': 65,
#    'timeSeconds': 3810,
#    'draw': {'start': {'x': 70.18444496654391, 'y': 7},
#     'end': {'x': 11.240437371172874, 'y': 0},
#     'goal': {'x': 83.95369770819721, 'y': 100}},
#    'reversedPeriodTime': 27,
#    'reversedPeriodTimeSeconds': 1590,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Moritz Broschinski',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'moritz-broschinski',
#     'shortName': 'M. Broschinski',
#     'position': 'F',
#     'jerseyNumber': '29',
#     'userCount': 107,
#     'id': 924205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'موريتز بروشينسكي'},
#      'shortNameTranslation': {'ar': 'م. بروشينسكي'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 3.366958869455215, 'y': 8.1705044250225, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 78.5313950869425, 'z': 16.5},
#    'blockCoordinates': {'x': 1, 'y': 3.6832930958286454, 'z': 0},
#    'xg': 0.22371502220631,
#    'xgot': 0.0501,
#    'id': 2772372,
#    'time': 66,
#    'timeSeconds': 3809,
#    'draw': {'start': {'x': 16.501960484746846, 'y': 3.643851663627042},
#     'block': {'x': 74.09114444212024, 'y': 1},
#     'end': {'x': 63.90752394596951, 'y': 0},
#     'goal': {'x': 0.23114130978842695, 'y': 54.55013153608962}},
#    'reversedPeriodTime': 27,
#    'reversedPeriodTimeSeconds': 1591,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Wout Weghorst',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'wout-weghorst',
#     'shortName': 'W. Weghorst',
#     'position': 'F',
#     'jerseyNumber': '10',
#     'userCount': 8485,
#     'id': 252215,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فوتر فيغورست'},
#      'shortNameTranslation': {'ar': 'ف. فيغورست'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 10.526395281030764,
#     'y': 56.37435067564015,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 19.471192215269014, 'z': 19},
#    'blockCoordinates': {'x': 3.6002155867044263,
#     'y': 79.30085451752086,
#     'z': 0},
#    'xg': 0.029995709657669,
#    'xgot': 0.0337,
#    'id': 2772360,
#    'time': 62,
#    'timeSeconds': 3764,
#    'draw': {'start': {'x': 93.15103451021332, 'y': 18.49207633530166},
#     'block': {'x': 50.628725339482095, 'y': 2.3574917168319556},
#     'end': {'x': 41.01501217409552, 'y': 0},
#     'goal': {'x': 82.69357019744142, 'y': 81}},
#    'reversedPeriodTime': 28,
#    'reversedPeriodTimeSeconds': 1636,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Anthony Losilla',
#     'slug': 'anthony-losilla',
#     'shortName': 'A. Losilla',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 179,
#     'id': 119179,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أنتوني لوسيلا'},
#      'shortNameTranslation': {'ar': 'أ. لوسيلا'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 0.06314508172037847,
#     'y': 57.22548004581076,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'left',
#    'goalMouthCoordinates': {'x': 0, 'y': 56.17864752949357, 'z': 9.7},
#    'xg': 0.036061946302652,
#    'id': 2772341,
#    'time': 68,
#    'timeSeconds': 3548,
#    'draw': {'start': {'x': 100, 'y': 15.476644251060776},
#     'end': {'x': 29.326293241507607, 'y': 0},
#     'goal': {'x': 0.42507128214491274, 'y': 100}},
#    'reversedPeriodTime': 31,
#    'reversedPeriodTimeSeconds': 1852,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Moritz Broschinski',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'moritz-broschinski',
#     'shortName': 'M. Broschinski',
#     'position': 'F',
#     'jerseyNumber': '29',
#     'userCount': 107,
#     'id': 924205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'موريتز بروشينسكي'},
#      'shortNameTranslation': {'ar': 'م. بروشينسكي'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'throw-in-set-piece',
#    'playerCoordinates': {'x': 14.917517868904618, 'y': 55, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 40.16336835729976, 'z': 63.9},
#    'xg': 0.084131672978401,
#    'id': 2772330,
#    'time': 51,
#    'timeSeconds': 3423,
#    'draw': {'start': {'x': 55, 'y': 9.879306152596975},
#     'end': {'x': 55.037123811357844, 'y': 0},
#     'goal': {'x': 65.02132295620682, 'y': 34.71475678280141}},
#    'reversedPeriodTime': 33,
#    'reversedPeriodTimeSeconds': 1977,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Maximilian Wittek',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'maximilian-wittek',
#     'shortName': 'M. Wittek',
#     'position': 'D',
#     'jerseyNumber': '32',
#     'userCount': 170,
#     'id': 254125,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ماكسيميليان ويتك'},
#      'shortNameTranslation': {'ar': 'م. ويتك'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 6.961403133181474,
#     'y': 23.713862500907517,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 78.34884868414093, 'z': 4.4},
#    'blockCoordinates': {'x': 0.31122869957522203,
#     'y': 66.57192138841162,
#     'z': 0},
#    'xg': 0.029907617717981,
#    'xgot': 0.2281,
#    'id': 2772317,
#    'time': 49,
#    'timeSeconds': 3298,
#    'draw': {'start': {'x': 57.5935241531999, 'y': 25.796926130342737},
#     'block': {'x': 74.32955487668227, 'y': 2.322660340522898},
#     'end': {'x': 81.65007763562673, 'y': 0},
#     'goal': {'x': 41.42917384174458, 'y': 100}},
#    'reversedPeriodTime': 36,
#    'reversedPeriodTimeSeconds': 2102,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kevin Stöger',
#     'slug': 'kevin-stoger',
#     'shortName': 'K. Stöger',
#     'position': 'M',
#     'jerseyNumber': '7',
#     'userCount': 650,
#     'id': 95381,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شتوغر, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شتوغر'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 7.596217770185788, 'y': 100, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 37.412978341897684, 'z': 79.2},
#    'xg': 0.040896624326706,
#    'id': 2772302,
#    'time': 55,
#    'timeSeconds': 3213,
#    'draw': {'start': {'x': 100, 'y': 29.43549039117929},
#     'end': {'x': 6.53079293412415, 'y': 0},
#     'goal': {'x': 72.2215714469531, 'y': 27.966442937281}},
#    'reversedPeriodTime': 37,
#    'reversedPeriodTimeSeconds': 2187,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Keven Schlotterbeck',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'keven-schlotterbeck',
#     'shortName': 'K. Schlotterbeck',
#     'position': 'D',
#     'jerseyNumber': '31',
#     'userCount': 383,
#     'id': 891651,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شلوتيربيك, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شلوتيربيك'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'throw-in-set-piece',
#    'playerCoordinates': {'x': 4.410638150564141,
#     'y': 38.635829451069185,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 19, 'z': 12.5},
#    'blockCoordinates': {'x': 15.621416076858392,
#     'y': 91.51543180802992,
#     'z': 0},
#    'xg': 0.04597570002079,
#    'id': 2772320,
#    'time': 52,
#    'timeSeconds': 3121,
#    'draw': {'start': {'x': 7.775950360720927, 'y': 7.785707362973435},
#     'block': {'x': 8.35047392521701, 'y': 5.675175656514831},
#     'end': {'x': 81, 'y': 0},
#     'goal': {'x': 81, 'y': 41.89151860177884}},
#    'reversedPeriodTime': 38,
#    'reversedPeriodTimeSeconds': 2279,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Moritz Broschinski',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'moritz-broschinski',
#     'shortName': 'M. Broschinski',
#     'position': 'F',
#     'jerseyNumber': '29',
#     'userCount': 107,
#     'id': 924205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'موريتز بروشينسكي'},
#      'shortNameTranslation': {'ar': 'م. بروشينسكي'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'throw-in-set-piece',
#    'playerCoordinates': {'x': 7.408835541237007,
#     'y': 72.21562059311515,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 99.58510850271192, 'z': 19},
#    'blockCoordinates': {'x': 3.955766388940784,
#     'y': 81.53395022851765,
#     'z': 0},
#    'xg': 0.083889171481133,
#    'id': 2772312,
#    'time': 53,
#    'timeSeconds': 3120,
#    'draw': {'start': {'x': 57.39444873609106, 'y': 11.369795441539274},
#     'block': {'x': 95.83627530088236, 'y': 13.920141335338869},
#     'end': {'x': 37.462108074563204, 'y': 0},
#     'goal': {'x': 62.71628090588031, 'y': 81}},
#    'reversedPeriodTime': 38,
#    'reversedPeriodTimeSeconds': 2280,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Bernardo',
#     'slug': 'bernardo',
#     'shortName': 'Bernardo',
#     'position': 'D',
#     'jerseyNumber': '5',
#     'userCount': 353,
#     'id': 828571,
#     'fieldTranslations': {'nameTranslation': {'ar': 'برناردو'},
#      'shortNameTranslation': {'ar': 'برناردو'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 15.507287205459741,
#     'y': 27.007435333891372,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 36.53272115553796, 'z': 9.7},
#    'blockCoordinates': {'x': 4.996813850647834, 'y': 100, 'z': 0},
#    'xg': 0.070240780711174,
#    'id': 2772296,
#    'time': 50,
#    'timeSeconds': 3095,
#    'draw': {'start': {'x': 21.099668969046483, 'y': 8.649033368987299},
#     'block': {'x': 2.9139288400922823, 'y': 4.0787280920523985},
#     'end': {'x': 70.71993304290751, 'y': 0},
#     'goal': {'x': 73.91433363830706, 'y': 85.15709544091904}},
#    'reversedPeriodTime': 39,
#    'reversedPeriodTimeSeconds': 2305,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Keven Schlotterbeck',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'keven-schlotterbeck',
#     'shortName': 'K. Schlotterbeck',
#     'position': 'D',
#     'jerseyNumber': '31',
#     'userCount': 383,
#     'id': 891651,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شلوتيربيك, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شلوتيربيك'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 6.637783651432955,
#     'y': 43.56551755411299,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 75.7675876676912, 'z': 6.3},
#    'blockCoordinates': {'x': 1.8021813887840517,
#     'y': 51.956952315081274,
#     'z': 0},
#    'xg': 0.021776920184493,
#    'xgot': 0.1288,
#    'id': 2772294,
#    'time': 45,
#    'timeSeconds': 3065,
#    'draw': {'start': {'x': 36.0289445365373, 'y': 5.6781741699460975},
#     'block': {'x': 26.663571629528327, 'y': 1.8129070814785715},
#     'end': {'x': 9.322229783612002, 'y': 0},
#     'goal': {'x': 1.1283396127785608, 'y': 4.8964202722433185}},
#    'reversedPeriodTime': 39,
#    'reversedPeriodTimeSeconds': 2335,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Anthony Losilla',
#     'slug': 'anthony-losilla',
#     'shortName': 'A. Losilla',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 179,
#     'id': 119179,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أنتوني لوسيلا'},
#      'shortNameTranslation': {'ar': 'أ. لوسيلا'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 14.126258063262, 'y': 4.495486947348226, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 70.90848316439528, 'z': 21.5},
#    'blockCoordinates': {'x': 0.13792026542717117,
#     'y': 69.72064819235403,
#     'z': 0},
#    'xg': 0.054208811372519,
#    'xgot': 0.1875,
#    'id': 2772539,
#    'time': 52,
#    'timeSeconds': 2996,
#    'draw': {'start': {'x': 100, 'y': 23.316776349485977},
#     'block': {'x': 41.061063945051984, 'y': 0.4425002321287752},
#     'end': {'x': 95.24961844510415, 'y': 0},
#     'goal': {'x': 56.747314253541994, 'y': 33.75213721408997}},
#    'reversedPeriodTime': 41,
#    'reversedPeriodTimeSeconds': 2404,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Moritz Broschinski',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'moritz-broschinski',
#     'shortName': 'M. Broschinski',
#     'position': 'F',
#     'jerseyNumber': '29',
#     'userCount': 107,
#     'id': 924205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'موريتز بروشينسكي'},
#      'shortNameTranslation': {'ar': 'م. بروشينسكي'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 25.357203532173592,
#     'y': 32.99020232847346,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 21.133391691155666, 'z': 19},
#    'blockCoordinates': {'x': 17.53464493719814,
#     'y': 52.43668050941799,
#     'z': 0},
#    'xg': 0.017614683136344,
#    'id': 2772279,
#    'time': 36,
#    'timeSeconds': 2756,
#    'draw': {'start': {'x': 31.28588427057791, 'y': 23.962953339170262},
#     'block': {'x': 10.03211077596081, 'y': 22.796001690098862},
#     'end': {'x': 78.92887938576872, 'y': 0},
#     'goal': {'x': 34.31415261104962, 'y': 81}},
#    'reversedPeriodTime': 45,
#    'reversedPeriodTimeSeconds': 2644,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kevin Stöger',
#     'slug': 'kevin-stoger',
#     'shortName': 'K. Stöger',
#     'position': 'M',
#     'jerseyNumber': '7',
#     'userCount': 650,
#     'id': 95381,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شتوغر, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شتوغر'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 0.8691680631959668,
#     'y': 3.955926095564319,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 23.439213183906297, 'z': 19},
#    'blockCoordinates': {'x': 2.142952495997292,
#     'y': 40.53770709039515,
#     'z': 0},
#    'xg': 0.0057343556545675,
#    'id': 2772276,
#    'time': 54,
#    'timeSeconds': 2750,
#    'draw': {'start': {'x': 48.388753052411005, 'y': 4.134235625301306},
#     'block': {'x': 19.759387151233724, 'y': 2.8831956054749317},
#     'end': {'x': 42.68857455132363, 'y': 0},
#     'goal': {'x': 86.93704589575111, 'y': 81}},
#    'reversedPeriodTime': 45,
#    'reversedPeriodTimeSeconds': 2650,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Moritz Broschinski',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'moritz-broschinski',
#     'shortName': 'M. Broschinski',
#     'position': 'F',
#     'jerseyNumber': '29',
#     'userCount': 107,
#     'id': 924205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'موريتز بروشينسكي'},
#      'shortNameTranslation': {'ar': 'م. بروشينسكي'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 16.2147624960652,
#     'y': 22.76438099911705,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 89.6305521046329, 'z': 13.9},
#    'blockCoordinates': {'x': 1.4745240875896863,
#     'y': 11.363849524679239,
#     'z': 0},
#    'xg': 0.019957516342402,
#    'id': 2772272,
#    'time': 40,
#    'timeSeconds': 2746,
#    'draw': {'start': {'x': 21.401145869436547, 'y': 1.8191917915309368},
#     'block': {'x': 25.208773860731725, 'y': 0.01793115666818501},
#     'end': {'x': 43.81003371206368, 'y': 0},
#     'goal': {'x': 61.27439314505791, 'y': 100}},
#    'reversedPeriodTime': 45,
#    'reversedPeriodTimeSeconds': 2654,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Maximilian Wittek',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'maximilian-wittek',
#     'shortName': 'M. Wittek',
#     'position': 'D',
#     'jerseyNumber': '32',
#     'userCount': 170,
#     'id': 254125,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ماكسيميليان ويتك'},
#      'shortNameTranslation': {'ar': 'م. ويتك'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 55.47938475626296, 'y': 100, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 26.49006371429148, 'z': 72.2},
#    'xg': 0.03816744685173,
#    'id': 2772120,
#    'time': 43,
#    'addedTime': 5,
#    'timeSeconds': 2955,
#    'draw': {'start': {'x': 39.70585272789475, 'y': 3.251846186028679},
#     'end': {'x': 9.704005380964176, 'y': 0},
#     'goal': {'x': 17.223606596874816, 'y': 4.379253904639331}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 2445,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Felix Passlack',
#     'slug': 'passlack-felix',
#     'shortName': 'F. Passlack',
#     'position': 'M',
#     'jerseyNumber': '15',
#     'userCount': 360,
#     'id': 795000,
#     'fieldTranslations': {'nameTranslation': {'ar': 'باسلاك, فيليكس'},
#      'shortNameTranslation': {'ar': 'ف. باسلاك'}}},
#    'isHome': False,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 7.889931466864866,
#     'y': 49.45944583124967,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 26.735486921379227, 'z': 13.9},
#    'xg': 0.28751674294472,
#    'xgot': 0.9495,
#    'id': 2772104,
#    'time': 45,
#    'addedTime': 2,
#    'timeSeconds': 2790,
#    'draw': {'start': {'x': 100, 'y': 9.819765975388343},
#     'end': {'x': 44.58944716409848, 'y': 0},
#     'goal': {'x': 41.39015040425989, 'y': 100}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 2610,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Umut Tohumcu',
#     'firstName': 'Umut Tohumcu',
#     'lastName': '',
#     'slug': 'umut-tohumcu',
#     'shortName': 'U. Tohumcu',
#     'position': 'M',
#     'jerseyNumber': '40',
#     'userCount': 277,
#     'id': 1083410,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أوموت توهومكو'},
#      'shortNameTranslation': {'ar': 'أ. توهومكو'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 2.554396462848782,
#     'y': 22.470813952461775,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 62.407422684338066, 'z': 19},
#    'blockCoordinates': {'x': 20.892201175439265,
#     'y': 67.58973076211204,
#     'z': 0},
#    'xg': 0.047692831605673,
#    'id': 2771987,
#    'time': 39,
#    'timeSeconds': 2126,
#    'draw': {'start': {'x': 77.09797303690164, 'y': 36.64659195151048},
#     'block': {'x': 21.195477693512316, 'y': 17.18354037896881},
#     'end': {'x': 49.054369724460464, 'y': 0},
#     'goal': {'x': 22.593995895424293, 'y': 81}},
#    'reversedPeriodTime': 10,
#    'reversedPeriodTimeSeconds': 574,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kevin Stöger',
#     'slug': 'kevin-stoger',
#     'shortName': 'K. Stöger',
#     'position': 'M',
#     'jerseyNumber': '7',
#     'userCount': 650,
#     'id': 95381,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شتوغر, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شتوغر'}}},
#    'isHome': True,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 23.338233416755767,
#     'y': 22.972491872608458,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 3.4137218099315874, 'z': 28.5},
#    'xg': 0.137844145298,
#    'xgot': 0.6342,
#    'id': 2771980,
#    'time': 41,
#    'timeSeconds': 2017,
#    'draw': {'start': {'x': 68.94151303326332, 'y': 17.861411414498303},
#     'end': {'x': 48.643038790656895, 'y': 0},
#     'goal': {'x': 56.720238135012416, 'y': 19.056118424977612}},
#    'reversedPeriodTime': 12,
#    'reversedPeriodTimeSeconds': 683,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Moritz Broschinski',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'moritz-broschinski',
#     'shortName': 'M. Broschinski',
#     'position': 'F',
#     'jerseyNumber': '29',
#     'userCount': 107,
#     'id': 924205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'موريتز بروشينسكي'},
#      'shortNameTranslation': {'ar': 'م. بروشينسكي'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 13.261801673132029, 'y': 100, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 44.76289187342167, 'z': 12},
#    'blockCoordinates': {'x': 0.826694216788415,
#     'y': 69.82248507056096,
#     'z': 0},
#    'xg': 0.24346929788589,
#    'xgot': 0.2966,
#    'id': 2771977,
#    'time': 25,
#    'timeSeconds': 1935,
#    'draw': {'start': {'x': 10.70934017820663, 'y': 12.776419754117972},
#     'block': {'x': 20.2292715800735, 'y': 1.734327476503073},
#     'end': {'x': 84.71572715516129, 'y': 0},
#     'goal': {'x': 37.44942171637327, 'y': 88}},
#    'reversedPeriodTime': 13,
#    'reversedPeriodTimeSeconds': 765,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Maximilian Wittek',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'maximilian-wittek',
#     'shortName': 'M. Wittek',
#     'position': 'D',
#     'jerseyNumber': '32',
#     'userCount': 170,
#     'id': 254125,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ماكسيميليان ويتك'},
#      'shortNameTranslation': {'ar': 'م. ويتك'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 6.959371994592006, 'y': 35, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 100, 'z': 62.5},
#    'xg': 0.16452306509018,
#    'id': 2771969,
#    'time': 35,
#    'timeSeconds': 1870,
#    'draw': {'start': {'x': 35, 'y': 9.914816639914841},
#     'end': {'x': 10.16975017019238, 'y': 0},
#     'goal': {'x': 77.56621830736125, 'y': 14.42451424555395}},
#    'reversedPeriodTime': 14,
#    'reversedPeriodTimeSeconds': 830,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Grischa Prömel',
#     'slug': 'grischa-promel',
#     'shortName': 'G. Prömel',
#     'position': 'M',
#     'jerseyNumber': '6',
#     'userCount': 266,
#     'id': 253993,
#     'fieldTranslations': {'nameTranslation': {'ar': 'بروميل, غريشا'},
#      'shortNameTranslation': {'ar': 'غ. بروميل'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 16.70286780120015,
#     'y': 5.657709171487603,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'close-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 47.33094421451392, 'z': 9.7},
#    'xg': 0.11819861829281,
#    'id': 2771961,
#    'time': 21,
#    'timeSeconds': 1737,
#    'draw': {'start': {'x': 55.84572179037296, 'y': 7.142506310045979},
#     'end': {'x': 82.35184827567761, 'y': 0},
#     'goal': {'x': 35.42827470895635, 'y': 9.248634607995868}},
#    'reversedPeriodTime': 17,
#    'reversedPeriodTimeSeconds': 963,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Maximilian Beier',
#     'slug': 'maximilian-beier',
#     'shortName': 'M. Beier',
#     'position': 'F',
#     'jerseyNumber': '14',
#     'userCount': 1342,
#     'id': 980628,
#     'fieldTranslations': {'nameTranslation': {'ar': 'بيير, ماكسيميليان'},
#      'shortNameTranslation': {'ar': 'م. بيير'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'fast-break',
#    'playerCoordinates': {'x': 30.343347139451524,
#     'y': 25.42963967153632,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 78.47321117720823, 'z': 19},
#    'blockCoordinates': {'x': 17.827178641449706,
#     'y': 17.447567899304346,
#     'z': 0},
#    'xg': 0.034475032240152,
#    'id': 2771940,
#    'time': 16,
#    'timeSeconds': 1360,
#    'draw': {'start': {'x': 44.49666006415326, 'y': 26.607278756441005},
#     'block': {'x': 42.837766277541206, 'y': 19.65339591940638},
#     'end': {'x': 95.37675592535776, 'y': 0},
#     'goal': {'x': 74.44124267000267, 'y': 81}},
#    'reversedPeriodTime': 23,
#    'reversedPeriodTimeSeconds': 1340,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Anthony Losilla',
#     'slug': 'anthony-losilla',
#     'shortName': 'A. Losilla',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 179,
#     'id': 119179,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أنتوني لوسيلا'},
#      'shortNameTranslation': {'ar': 'أ. لوسيلا'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 5.152891223335304,
#     'y': 66.53594330468157,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 0.17524509984905734, 'z': 76.4},
#    'xg': 0.02508263476193,
#    'id': 2771887,
#    'time': 18,
#    'timeSeconds': 756,
#    'draw': {'start': {'x': 23.18154012624329, 'y': 1.8563817516348582},
#     'end': {'x': 64.40405503619633, 'y': 0},
#     'goal': {'x': 75.14674215163248, 'y': 15.90380251166706}},
#    'reversedPeriodTime': 33,
#    'reversedPeriodTimeSeconds': 1944,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Wout Weghorst',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'wout-weghorst',
#     'shortName': 'W. Weghorst',
#     'position': 'F',
#     'jerseyNumber': '10',
#     'userCount': 8485,
#     'id': 252215,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فوتر فيغورست'},
#      'shortNameTranslation': {'ar': 'ف. فيغورست'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 9.947191437493835,
#     'y': 71.46427216061714,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 81.62650995068516, 'z': 19},
#    'blockCoordinates': {'x': 13.556256962733224,
#     'y': 34.57548249804866,
#     'z': 0},
#    'xg': 0.11274870485067,
#    'id': 2771880,
#    'time': 5,
#    'timeSeconds': 654,
#    'draw': {'start': {'x': 32.351556617168214, 'y': 19.696837883552774},
#     'block': {'x': 68.7756549049761, 'y': 13.35818655104317},
#     'end': {'x': 75.74250583970193, 'y': 0},
#     'goal': {'x': 11.696623444712941, 'y': 81}},
#    'reversedPeriodTime': 35,
#    'reversedPeriodTimeSeconds': 2046,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kevin Stöger',
#     'slug': 'kevin-stoger',
#     'shortName': 'K. Stöger',
#     'position': 'M',
#     'jerseyNumber': '7',
#     'userCount': 650,
#     'id': 95381,
#     'fieldTranslations': {'nameTranslation': {'ar': 'شتوغر, كيفن'},
#      'shortNameTranslation': {'ar': 'ك. شتوغر'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 23, 'y': 75.2022449120802, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'close-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 42, 'z': 6.9},
#    'xg': 0.012490652501583,
#    'id': 2771871,
#    'time': 17,
#    'timeSeconds': 583,
#    'draw': {'start': {'x': 37.55931824489162, 'y': 23},
#     'end': {'x': 58, 'y': 0},
#     'goal': {'x': 58, 'y': 100}},
#    'reversedPeriodTime': 36,
#    'reversedPeriodTimeSeconds': 2117,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Felix Passlack',
#     'slug': 'passlack-felix',
#     'shortName': 'F. Passlack',
#     'position': 'M',
#     'jerseyNumber': '15',
#     'userCount': 360,
#     'id': 795000,
#     'fieldTranslations': {'nameTranslation': {'ar': 'باسلاك, فيليكس'},
#      'shortNameTranslation': {'ar': 'ف. باسلاك'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 24, 'y': 81.94830891276331, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 55.57300867397333, 'z': 19},
#    'blockCoordinates': {'x': 38.55577150187908,
#     'y': 1.7255121071102408,
#     'z': 0},
#    'xg': 0.025798738002777,
#    'id': 2771864,
#    'time': 9,
#    'timeSeconds': 562,
#    'draw': {'start': {'x': 100, 'y': 24},
#     'block': {'x': 41.32516507905022, 'y': 1.3846999516917649},
#     'end': {'x': 36.254179098369896, 'y': 0},
#     'goal': {'x': 59.41991796996897, 'y': 81}},
#    'reversedPeriodTime': 36,
#    'reversedPeriodTimeSeconds': 2138,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Anthony Losilla',
#     'slug': 'anthony-losilla',
#     'shortName': 'A. Losilla',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 179,
#     'id': 119179,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أنتوني لوسيلا'},
#      'shortNameTranslation': {'ar': 'أ. لوسيلا'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 5.512119592774701,
#     'y': 43.92249703228271,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 3.2325650805737496, 'z': 19},
#    'blockCoordinates': {'x': 7.870548818900229,
#     'y': 26.061404660606925,
#     'z': 0},
#    'xg': 0.030527494847775,
#    'id': 2771855,
#    'time': 15,
#    'timeSeconds': 407,
#    'draw': {'start': {'x': 100, 'y': 20.86259453828638},
#     'block': {'x': 47.92155755508179, 'y': 11.81506481125021},
#     'end': {'x': 47.15710640262957, 'y': 0},
#     'goal': {'x': 96.24089644809871, 'y': 81}},
#    'reversedPeriodTime': 39,
#    'reversedPeriodTimeSeconds': 2293,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Philipp Hofmann',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'philipp-hofmann',
#     'shortName': 'P. Hofmann',
#     'position': 'F',
#     'jerseyNumber': '33',
#     'userCount': 506,
#     'id': 340719,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فيليپ هوفمان'},
#      'shortNameTranslation': {'ar': 'ف. هوفمان'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 7, 'y': 31.118286534616885, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 24.50862894563619, 'z': 11.4},
#    'blockCoordinates': {'x': 2.437599663866258,
#     'y': 18.520448096146417,
#     'z': 0},
#    'xg': 0.086844064295292,
#    'xgot': 0.034,
#    'id': 2771845,
#    'time': 10,
#    'timeSeconds': 341,
#    'draw': {'start': {'x': 25.152493966393777, 'y': 7},
#     'block': {'x': 36.828779598610204, 'y': 1.758362208797195},
#     'end': {'x': 34.26022477479657, 'y': 0},
#     'goal': {'x': 13.908487115929368, 'y': 82.13759011246012}},
#    'reversedPeriodTime': 40,
#    'reversedPeriodTimeSeconds': 2359,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Ivan Ordets',
#     'slug': 'ivan-ordets',
#     'shortName': 'I. Ordets',
#     'position': 'D',
#     'jerseyNumber': '20',
#     'userCount': 153,
#     'id': 137673,
#     'fieldTranslations': {'nameTranslation': {'ar': 'إيفان أورديت'},
#      'shortNameTranslation': {'ar': 'إ. أورديت'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 7.075535407226164,
#     'y': 45.71938588036721,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 56.83555853792641, 'z': 63.9},
#    'xg': 0.32020729780197,
#    'id': 2771833,
#    'time': 14,
#    'timeSeconds': 249,
#    'draw': {'start': {'x': 44.051151519135786, 'y': 3.8023663876419604},
#     'end': {'x': 7.877117343135396, 'y': 0},
#     'goal': {'x': 74.24960120310718, 'y': 13.391910491418749}},
#    'reversedPeriodTime': 41,
#    'reversedPeriodTimeSeconds': 2451,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Philipp Hofmann',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'philipp-hofmann',
#     'shortName': 'P. Hofmann',
#     'position': 'F',
#     'jerseyNumber': '33',
#     'userCount': 506,
#     'id': 340719,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فيليپ هوفمان'},
#      'shortNameTranslation': {'ar': 'ف. هوفمان'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 8, 'y': 38, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 22.31620233312102, 'z': 5.7},
#    'blockCoordinates': {'x': 0.3646966087975507, 'y': 48, 'z': 0},
#    'xg': 0.074242547154427,
#    'xgot': 0.1984,
#    'id': 2771832,
#    'time': -2,
#    'timeSeconds': 210,
#    'draw': {'start': {'x': 38, 'y': 8},
#     'block': {'x': 48, 'y': 1.0966779453891324},
#     'end': {'x': 79.00040324224443, 'y': 0},
#     'goal': {'x': 34.38681026133475, 'y': 100}},
#    'reversedPeriodTime': 42,
#    'reversedPeriodTimeSeconds': 2490,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Matúš Bero',
#     'slug': 'matus-bero',
#     'shortName': 'M. Bero',
#     'position': 'M',
#     'jerseyNumber': '19',
#     'userCount': 320,
#     'id': 187207,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ماتوس بيرو'},
#      'shortNameTranslation': {'ar': 'م. بيرو'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 27.367963517359055,
#     'y': 18.735452884549694,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 75.40458166802466, 'z': 19},
#    'blockCoordinates': {'x': 15.638494578605947,
#     'y': 20.407085545619182,
#     'z': 0},
#    'xg': 0.015353715978563,
#    'id': 2771840,
#    'time': -3,
#    'timeSeconds': 196,
#    'draw': {'start': {'x': 38.88894424213167, 'y': 49.83188012318661},
#     'block': {'x': 38.28390611978142, 'y': 36.43220030501588},
#     'end': {'x': 74.17311279934742, 'y': 0},
#     'goal': {'x': 81.77800962624733, 'y': 81}},
#    'reversedPeriodTime': 42,
#    'reversedPeriodTimeSeconds': 2504,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Philipp Hofmann',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'philipp-hofmann',
#     'shortName': 'P. Hofmann',
#     'position': 'F',
#     'jerseyNumber': '33',
#     'userCount': 506,
#     'id': 340719,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فيليپ هوفمان'},
#      'shortNameTranslation': {'ar': 'ف. هوفمان'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 2.8292474380244244,
#     'y': 84.32801671012967,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 54.07439143386945, 'z': 24.1},
#    'blockCoordinates': {'x': 2, 'y': 60.92511023087645, 'z': 0},
#    'xg': 0.053242094814777,
#    'xgot': 0.1125,
#    'id': 2771825,
#    'time': -3,
#    'timeSeconds': 131,
#    'draw': {'start': {'x': 44.39721431511635, 'y': 6.931763658714239},
#     'block': {'x': 53.707182681869874, 'y': 2},
#     'end': {'x': 5.520217403187409, 'y': 0},
#     'goal': {'x': 49.49397620333848, 'y': 22.434723667068496}},
#    'reversedPeriodTime': 43,
#    'reversedPeriodTimeSeconds': 2569,
#    'incidentType': 'shot'}]}
